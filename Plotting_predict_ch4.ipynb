# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ccsd_ene = [ 52.27812655,  44.26784982,  42.62628204,  37.25325966,  36.02123621,
  45.55234734,  59.47963926,  62.17281901,  59.62678644,  56.34922253,
  52.11875436,  43.42684211,  33.32479271,  28.56214275,  31.1318115,
  36.26081888,  43.06461584,  56.7944684 ,  42.70194989,  24.37940562,
   6.44445159, -10.45143008, -21.00264782, -26.96548922, -26.33573335,
 -25.04788655, -24.0942015 , -24.55650087, -26.94687123, -31.43444889,
 -44.4876097 , -50.48836566, -50.48836566, -55.69161996, -59.98397521,
 -63.6046663 , -65.58599004, -72.04355127, -72.55430539, -71.90258381,
 -71.2833757 , -69.78955664, -66.78669508, -63.25847594, -61.56630283,
 -60.14015234, -57.76444395, -53.51888587]

# %%
slatm = [53.1064  ,  46.540592,  43.455383,  37.79543 ,  35.578575,
        45.38092 ,  58.46221 ,  60.508232,  58.384506,  55.68268 ,
        51.656097,  43.64345 ,  33.456123,  29.746838,  33.187164,
        36.38813 ,  42.869648,  56.88835 ,  45.70493 ,  25.84713 ,
         9.367691,  -6.945532, -16.696796, -24.778772, -23.534222,
       -23.933075, -22.08749 , -23.115587, -26.07928 , -30.276173,
       -43.842953, -49.81963 , -49.81963 , -54.517395, -59.26066 ,
       -63.03125 , -64.676125, -71.22018 , -71.7085  , -70.943985,
       -70.31984 , -69.093   , -65.956955, -62.133125, -59.7608  ,
       -59.062054, -56.74152 , -52.046352]

# %%
# sns.set(rc={'axes.facecolor':'F5F5F5'})
sns.set_context("talk", font_scale=1.1)  
sns.set_style("whitegrid")
x = range(len(ccsd_ene))
line_2 = plt.scatter(x, ccsd_ene, c=sns.xkcd_rgb["sea blue"])
plt.xlabel("Time step")
plt.ylabel("Energy (kJ/mol)")
plt.savefig("ccsd.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
aslatm = [  52.05227 ,   45.148643,   42.8589   ,  36.656013,   34.22316 ,   42.952522,
  55.70896 ,   58.900555,   57.5781   ,  55.43422 ,   50.963905,   40.885406,
  32.11294 ,   27.01514 ,   29.419214 ,  33.95183 ,   40.695873,   56.48857,
  40.6261  ,   24.120785,    7.1595764,  -8.64476 ,  -19.161476,  -26.486023,
 -26.180508,  -26.136515,  -24.691235 , -24.81568 ,  -26.433247,  -30.42739,
 -43.56488 ,  -49.120285,  -49.120285 , -53.96223 ,  -58.15956 ,  -62.236183,
 -64.1744  ,  -71.167145,  -71.805984 , -71.38133 ,  -70.91943 ,  -69.286575,
 -66.07051 ,  -62.51628 ,  -60.96989  , -59.645195,  -57.295692,  -52.66039]

# %%
x = range(len(ccsd_ene))
sns.set()
line_1 = plt.scatter(x, slatm, c=sns.xkcd_rgb["medium green"], label="Predictions", marker="o")
line_2 = plt.scatter(x, ccsd_ene, c=sns.xkcd_rgb["denim blue"], label="True values", marker="o")
plt.xlabel("Time step")
plt.ylabel("Energy (kJ/mol)")
plt.ylim((-80, 70))
plt.legend(handles=[line_1, line_2])
plt.savefig("SLATM.png", dpi=200, bbox_inches='tight')
plt.show()

# %%
x = range(len(ccsd_ene))
sns.set_style("whitegrid")
sns.set_context("talk", font_scale=1.1) 
line_1 = plt.scatter(x, slatm, c=sns.xkcd_rgb["pumpkin"], label="Predictions", marker="o")
line_2 = plt.scatter(x, ccsd_ene, c=sns.xkcd_rgb["sea blue"], label="True values", marker="o")
plt.xlabel("Time step", fontsize=15)
plt.ylabel("Energy (kJ/mol)", fontsize=15)
plt.ylim((-80, 70))
plt.legend(handles=[line_1, line_2])
plt.savefig("SLATM.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
x = range(len(ccsd_ene))
sns.set_style("whitegrid")
sns.set_context("talk", font_scale=1.1) 
line_1 = plt.scatter(x, aslatm, c=sns.xkcd_rgb["pumpkin"], label="Predictions", marker="o")
line_2 = plt.scatter(x, ccsd_ene, c=sns.xkcd_rgb["sea blue"], label="True values", marker="o")
plt.xlabel("Time step", fontsize=15)
plt.ylabel("Energy (kJ/mol)", fontsize=15)
plt.ylim((-80, 70))
plt.legend(handles=[line_1, line_2])
plt.savefig("aSLATM.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
acsf_predict = [  56.43331  ,  42.894726 ,  37.25496  ,  33.793404 ,  36.96228  ,
        48.234467 ,  59.922455 ,  60.99112  ,  58.51362  ,  56.489124 ,
        53.266876 ,  45.231995 ,  35.259922 ,  29.62379  ,  30.62379  ,
        35.245365 ,  42.59826  ,  55.348923 ,  42.82575  ,  24.633333 ,
         6.2765045,  -9.001892 , -18.103271 , -24.51212  , -24.300858 ,
       -23.32999  , -23.232313 , -24.234089 , -25.928663 , -28.735756 ,
       -41.459316 , -49.134087 , -49.134087 , -55.971    , -60.698025 ,
       -63.88259  , -65.31783  , -69.107864 , -69.74757  , -69.52431  ,
       -68.50271  , -66.255936 , -63.13663  , -59.830574 , -59.074486 ,
       -60.813976 , -58.406628 , -53.28088  ]

# %%
sns.set(rc={'axes.facecolor':'F5F5F5'})
x = range(len(ccsd_ene))
line_1 = plt.scatter(x, acsf_predict, c=sns.xkcd_rgb["pumpkin"], label="Predictions")
line_2 = plt.scatter(x, ccsd_ene, c=sns.xkcd_rgb["sea blue"], label="True values")
plt.xlabel("Time step")
plt.ylabel("Energy (kJ/mol)")
plt.legend(handles=[line_1, line_2])
plt.savefig("acsf.png", dpi=300)
plt.show()
