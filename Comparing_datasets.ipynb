# %%
import glob
import numpy as np
import seaborn as sns
import sys
sys.path.insert(0, '/Volumes/Transcend/repositories/Aglaia/data_manip')
import data_utils as dt

# %%
energies_train= np.loadtxt('/Volumes/Transcend/useful_scripts/properties_Ha.txt', usecols=[1])

# %%
energies_test = np.loadtxt('/Volumes/Transcend/useful_scripts/properties.txt', usecols=[1])

# %%
import matplotlib.pyplot as plt
sns.set()
x_train = range(len(energies_train))
x_test = range(len(energies_test))
plt.scatter(x_train, energies_train)
plt.scatter(x_test, energies_test)
plt.show()

# %%
plt.scatter(x_test, energies_test)
plt.show()
